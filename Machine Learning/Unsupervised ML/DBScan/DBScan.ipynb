# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating synthetic dataset
from sklearn.datasets import make_moons
X,y = make_moons(n_samples=1000,noise=0.05,random_state=42)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.59996716,  0.31757343],
#        [ 0.55020965, -1.42528284],
#        [ 0.46649751, -1.26036633],
#        ...,
#        [ 1.34062188, -1.12206783],
#        [-1.66269509,  0.15973526],
#        [ 0.33988947,  0.72397143]])

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.3)

# %%
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3)

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=dbscan.labels_)

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(X=X_scaled,labels=dbscan.fit_predict(X_scaled))

# %%
score
# Out:
# 0.3911598537138403

# %%
plt.plot()
