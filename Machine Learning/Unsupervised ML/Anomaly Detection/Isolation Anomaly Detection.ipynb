# %% [markdown]
# ## Isolation Forest Anomaly Detection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('healthcare.csv')

# %%
df.head()
# Out:
#           0         1
# 0  1.616671  1.944522
# 1  1.256461  1.609444
# 2 -2.343919  4.392961
# 3  1.195393  2.794485
# 4 -3.329586  5.303160

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1])

# %%
from sklearn.ensemble import IsolationForest

# %%
an_forest = IsolationForest(contamination=0.2)

# %%
an_forest.fit(df)
# Out:
# IsolationForest(contamination=0.2)

# %%
prediction = an_forest.predict(df)

# %%
index = np.where(prediction<0)

# %%
index
# Out:
# (array([  4,  20,  24,  45,  48,  49,  53,  55,  60,  61,  62,  63,  67,
#          72,  74,  78,  83,  85,  87,  89,  92,  97, 104, 108, 114, 119,
#         126, 130, 132, 133, 141, 151, 160, 167, 177, 179, 181, 182, 187,
#         197, 199, 204, 212, 217, 220, 221, 227, 242, 247, 248], dtype=int64),)

# %%
x=df.values

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1])
plt.scatter(x[index,0],x[index,1],edgecolors='r')
