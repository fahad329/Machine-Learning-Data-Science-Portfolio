# %% [markdown]
# ## 5 Number Summary

# %%
import numpy as np

# %%
lst_marks = [45,34,32,48,56,54,67,66,65,71,76,78,98,56,43,89,82,95]
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks,[0,0.25,0.50,.75,1.0])

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 28.0

# %%
lower_fence  = Q1 - 1.5*(IQR) 
higher_fence = Q3 + 1.5*(IQR)

# %%
lower_fence
# Out:
# 7.5

# %%
higher_fence
# Out:
# 119.5

# %%
import seaborn as sns

# %%
lst_marks = [45,34,32,48,56,54,67,66,65,71,76,78,98,56,43,89,82,95,130]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
